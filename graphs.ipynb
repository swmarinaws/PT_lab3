# %%
from matplotlib import pyplot as plt

sizes = [100, 250, 500, 1000, 5000, 10000, 100000]
time_linear = [3.2100011594593525e-05, 6.230000872164965e-05, 0.00011999998241662979, 0.00028009997913613915, 0.0012694000033661723, 0.002439900010358542, 0.024302000005263835]
time_binary = [7.700000423938036e-06, 7.299997378140688e-06, 1.079996582120657e-05, 1.1100026313215494e-05, 1.3100041542202234e-05, 1.4899997040629387e-05, 1.6799953300505877e-05]
time_binary_sort = [0.0005262999911792576, 0.0013976999907754362, 0.0032272000098600984, 0.006752500019501895, 0.0404835999943316, 0.09307499998249114, 1.3847896999795921]
time_key = [7.280003046616912e-05, 1.3699987903237343e-05, 2.2099993657320738e-05, 2.95999925583601e-05, 4.269997589290142e-05, 5.920004332438111e-05, 6.900000153109431e-05]
time_simple = [1.309998333454132e-05, 9.800016414374113e-06, 1.0200019460171461e-05, 1.1599971912801266e-05, 1.3399985618889332e-05, 1.2699980288743973e-05, 0.00013749999925494194]
time_difficulty = [7.350003579631448e-05, 1.4399993233382702e-05, 1.3700046110898256e-05, 3.689998993650079e-05, 5.530001362785697e-05, 5.8999983593821526e-05, 7.619999814778566e-05]

plt.plot(sizes, time_linear, label='Прямой поиск', color="red")
plt.plot(sizes, time_binary, label='Бинарный поиск', color="orange")
plt.plot(sizes, time_binary_sort, label='Быстрая сортировка и бинарный поиск', color="yellow")
plt.plot(sizes, time_key, label='Поиск по ключу', color="purple")
plt.plot(sizes, time_simple, label='Поиск в хэш-таблице простой хэш-функции', color="blue")
plt.plot(sizes, time_difficulty, label='Поиск в хэш-таблице сложной хэш-функции', color="green")
plt.xlabel("Объём данных", alpha=0.5)
plt.ylabel("Время сортировки", alpha=0.5)
plt.legend()
plt.show()

# %%
plt.plot(sizes, time_linear, label='Прямой поиск', color="red")
plt.plot(sizes, time_binary, label='Бинарный поиск', color="orange")
plt.plot(sizes, time_key, label='Поиск по ключу', color="purple")
plt.plot(sizes, time_simple, label='Поиск в хэш-таблице простой хэш-функции', color="blue")
plt.plot(sizes, time_difficulty, label='Поиск в хэш-таблице сложной хэш-функции', color="green")
plt.xlabel("Объём данных", alpha=0.5)
plt.ylabel("Время сортировки", alpha=0.5)
plt.legend()
plt.show()

# %%
plt.plot(sizes, time_binary, label='Бинарный поиск', color="orange")
plt.plot(sizes, time_key, label='Поиск по ключу', color="purple")
plt.plot(sizes, time_simple, label='Поиск в хэш-таблице простой хэш-функции', color="blue")
plt.plot(sizes, time_difficulty, label='Поиск в хэш-таблице сложной хэш-функции', color="green")
plt.xlabel("Объём данных", alpha=0.5)
plt.ylabel("Время сортировки", alpha=0.5)
plt.legend()
plt.show()

# %%
collisions_simple = [16, 78, 225, 625, 4331, 9087, 74496]
collisions_difficulty = [0, 0, 0, 0, 0, 2, 195]
plt.plot(sizes, collisions_simple, label='Число коллизий простой хэш-функции', color="orange")
#plt.plot(sizes, collisions_difficulty, label='Число коллизий сложной хэш-функции', color="purple")
plt.xlabel("Объём данных", alpha=0.5)
plt.ylabel("Время сортировки", alpha=0.5)
plt.legend()
plt.show()

# %%
collisions_simple = [16, 78, 225, 625, 4331, 9087, 74496]
collisions_difficulty = [0, 0, 0, 0, 0, 2, 195]
#plt.plot(sizes, collisions_simple, label='Число коллизий простой хэш-функции', color="orange")
plt.plot(sizes, collisions_difficulty, label='Число коллизий сложной хэш-функции', color="purple")
plt.xlabel("Объём данных", alpha=0.5)
plt.ylabel("Время сортировки", alpha=0.5)
plt.legend()
plt.show()

# %%
collisions_simple = [16, 78, 225, 625, 4331, 9087, 74496]
collisions_difficulty = [0, 0, 0, 0, 0, 2, 195]
plt.plot(sizes, collisions_simple, label='Число коллизий простой хэш-функции', color="orange")
plt.plot(sizes, collisions_difficulty, label='Число коллизий сложной хэш-функции', color="purple")
plt.xlabel("Объём данных", alpha=0.5)
plt.ylabel("Время сортировки", alpha=0.5)
plt.legend()
plt.show()
